# %%
pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.39.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 134.0 kB/s eta 0:00:00 0:00:01
# Collecting reactivex>=4.0.4 (from influxdb-client)
#   Downloading reactivex-4.0.4-py3-none-any.whl (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 345.5 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (68.2.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (2.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.5.3->influxdb-client) (1.16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /opt/conda/lib/python3.11/site-packages (from reactivex>=4.0.4->influxdb-client) (4.8.0)
# Downloading influxdb_client-1.39.0-py3-none-any.whl (743 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.0/744.0 kB 1.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: reactivex, influxdb-client
# Successfully installed influxdb-client-1.39.0 reactivex-4.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/spark/python (3.5.0)
# Collecting py4j==0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 375.6 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: py4j
# Successfully installed py4j-0.10.9.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Real Time Data Extraction from InfluxDB

# %%
from influxdb_client import InfluxDBClient

# Replace with your InfluxDB details
influxdb_url = 'http://influxdb:8086'
token = 'ERKMHDv-dYn0HaOhHdTqr0eCLNm3kSXJ79aBgHqqAeAYLEDiCQk1zZYj6GBIbAFFLd-Iaeh85P4E5Y0tI5y4Vw=='
org = 'OST'
bucket = 'Epsymolo'

client = InfluxDBClient(url=influxdb_url, token=token, org=org)

query_api = client.query_api()
query = 'from(bucket: "Epsymolo")|> range(start: -1w)|> filter(fn: (r) => r["_field"] == "PowerFlowValue")|> keep(columns: ["_value", "_time", "PowerLineID"])'

# Execute the query
result = query_api.query(org=org, query=query)
for table in result:
    for record in table.records:
        print(record)
        break
    break
# Out:
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_time': datetime.datetime(2023, 12, 15, 0, 0, tzinfo=tzlocal()), '_value': 360.8533333333333, 'PowerLineID': '0'}

# %% [markdown]
# ## Loading Data into Spark DataFrame

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, TimestampType, DoubleType
from pyspark.sql.functions import lag, col
from pyspark.sql.window import Window

# Initialize Spark session
spark = SparkSession.builder.master("local").appName("AnomalyDetection").getOrCreate()

# Define the schema based on the structure of your data from InfluxDB
schema = StructType([
    StructField("PowerLineID", IntegerType(), True),
    StructField("Timestamp", TimestampType(), True),
    StructField("PowerFlowValue", DoubleType(), True)
])

# Initialize an empty list to hold data points
data_for_spark = []

for table in result:
    for record in table.records:
        # Extract the values and time for each record
        power_line_id = int(record['PowerLineID'])  # Cast PowerLineID to int
        timestamp = record['_time']
        power_flow_value = record['_value']
        data_point = (power_line_id, timestamp, power_flow_value)
        data_for_spark.append(data_point)

# Create a Spark DataFrame using the data and the schema
df_real_time = spark.createDataFrame(data_for_spark, schema=schema)
df_real_time.show()
# Out:
# +-----------+-------------------+------------------+
# |PowerLineID|          Timestamp|    PowerFlowValue|
# +-----------+-------------------+------------------+
# |          0|2023-12-15 00:00:00| 360.8533333333333|
# |          0|2023-12-15 01:00:00|            386.47|
# |          0|2023-12-15 02:00:00|            400.74|
# |          0|2023-12-15 03:00:00| 401.0808333333334|
# |          0|2023-12-15 04:00:00|419.02416666666664|
# |          0|2023-12-15 05:00:00| 434.6133333333333|
# |          0|2023-12-15 06:00:00|          387.5525|
# |          0|2023-12-15 07:00:00|353.23083333333335|
# |          0|2023-12-15 08:00:00| 285.8616666666666|
# |          0|2023-12-15 09:00:00|272.09166666666664|
# |          0|2023-12-15 10:00:00|219.03166666666667|
# |          0|2023-12-15 11:00:00|          165.2675|
# |          0|2023-12-15 12:00:00|145.92166666666665|
# |          0|2023-12-15 13:00:00|            210.71|
# |          0|2023-12-15 14:00:00| 267.6741666666667|
# |          0|2023-12-15 15:00:00|263.22833333333335|
# |          0|2023-12-15 16:00:00|          251.5875|
# |          0|2023-12-15 17:00:00|            295.05|
# |          0|2023-12-15 18:00:00|269.47499999999997|
# |          0|2023-12-15 19:00:00| 322.6741666666667|
# +-----------+-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Preprocess the Real Time data

# %% [markdown]
# ## Load the trained model

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.3.1

# %%
import joblib

# Load the model
model = joblib.load('model_1.joblib')

# %%
# Convert the Spark DataFrame to a Pandas DataFrame for scikit-learn
features_for_prediction = ['PowerLineID','PowerFlowValue', 'PowerChange']  # Replace with the actual features used during training
real_time_data_for_prediction = df_real_time.select(*features_for_prediction).toPandas()
# Make predictions with the scikit-learn model
predictions = model.predict(real_time_data_for_prediction)

# %%
# If you want to add the predictions back to the Spark DataFrame:
from pyspark.sql.types import IntegerType

# Add a new column for predictions
df_real_time = df_real_time.withColumn("Predicted_IsSignificantChange", lit(None).cast(IntegerType()))

# Convert to Pandas DataFrame to merge the predictions easily (assuming the data is small enough to fit into memory)
df_real_time_pandas = df_real_time.toPandas()

# Attach the predictions
df_real_time_pandas['Predicted_IsSignificantChange'] = predictions

# If you need to convert it back to a PySpark DataFrame
df_real_time_with_predictions = spark.createDataFrame(df_real_time_pandas)

# %%
df_real_time_with_predictions.show(40)
# Out:
# +-----------+-------------------+------------------+------------------+-------------------+-----------------------------+
# |PowerLineID|          Timestamp|    PowerFlowValue|PrevPowerFlowValue|        PowerChange|Predicted_IsSignificantChange|
# +-----------+-------------------+------------------+------------------+-------------------+-----------------------------+
# |          0|2023-12-15 02:00:00|            400.74|            386.47| 14.269999999999982|                            1|
# |          0|2023-12-15 03:00:00| 401.0808333333334|            400.74| 0.3408333333333644|                            0|
# |          0|2023-12-15 04:00:00|419.02416666666664| 401.0808333333334|  17.94333333333327|                            1|
# |          0|2023-12-16 13:00:00| 278.2658333333333|297.53416666666664|-19.268333333333317|                            1|
# |          0|2023-12-16 14:00:00| 226.9416666666667| 278.2658333333333| -51.32416666666663|                            1|
# |          0|2023-12-16 15:00:00|211.99666666666667| 226.9416666666667|-14.945000000000022|                            1|
# |          0|2023-12-16 16:00:00|215.51333333333332|211.99666666666667| 3.5166666666666515|                            1|
# |          0|2023-12-16 17:00:00|305.88916666666665|215.51333333333332|  90.37583333333333|                            1|
# +-----------+-------------------+------------------+------------------+-------------------+-----------------------------+
# only showing top 40 rows

# %% [markdown]
# ## Send Results to Results Topic

# %%
# Drop the 'PrevPowerFlowValue' column
df_real_time_pandas = df_real_time_pandas.drop(columns=['PrevPowerFlowValue'])

# %%
df_real_time_pandas.shape
# Out:
# (34652, 5)

# %%
from confluent_kafka import Producer
import json
import pandas as pd
import numpy as np

def delivery_report(err, msg):
    if err is not None:
        print(f"Delivery failed for message: {err}")
    else:
        print(f"Message delivered to {msg.topic()} [{msg.partition()}]")

def send_data_to_kafka(bootstrap_servers, topic, df):
    producer = Producer({'bootstrap.servers': bootstrap_servers})
    batch_size = 10000  # Define the batch size

    
    # Convert Timestamp to appropriate format if it's a datetime object
    if isinstance(df.iloc[0]['Timestamp'], pd.Timestamp):
        df['Timestamp'] = df['Timestamp'].apply(lambda x: int(x.timestamp()))

    # Split the DataFrame into chunks
    chunks = np.array_split(df, range(batch_size, len(df), batch_size))
    
    for chunk in chunks:
        print(f"Sending batch of {len(chunk)} rows")

        for index, row in chunk.iterrows():
            try:
                # Ensure 'PowerLineID' is a string and convert Timestamp
                row['PowerLineID'] = str(row['PowerLineID'])

                payload = json.dumps(row.to_dict())
                producer.produce(topic=topic, value=payload.encode('utf-8'), callback=delivery_report)
                producer.poll(0)

            except Exception as e:
                print(f"An error occurred: {e}")

        producer.flush()
        print(f"\nFinished sending batch of {len(chunk)} rows to Kafka topic {topic}")

if __name__ == "__main__":
    BOOTSTRAP_SERVER = 'kafka:9092'  # Replace with your actual bootstrap server
    TOPIC = 'Results'  # Replace with your actual topic

    # Assuming df_real_time_with_predictions is the DataFrame with your data
    send_data_to_kafka(BOOTSTRAP_SERVER, TOPIC, df_real_time_pandas)
# Out:
# Sending batch of 10000 rows
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# ...
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
# Message delivered to Results [0]
#
# Finished sending batch of 4652 rows to Kafka topic Results

# %%
from confluent_kafka import Consumer, KafkaException, KafkaError
import json
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# InfluxDB configuration
influxdb_url = 'http://influxdb:8086'  # Replace with your InfluxDB URL
token = 'ERKMHDv-dYn0HaOhHdTqr0eCLNm3kSXJ79aBgHqqAeAYLEDiCQk1zZYj6GBIbAFFLd-Iaeh85P4E5Y0tI5y4Vw=='  # Replace with your InfluxDB token
org = 'OST'  # Replace with your InfluxDB org
bucket = 'Epsymolo'  # Replace with your InfluxDB bucket

# Kafka configuration
kafka_conf = {
    'bootstrap.servers': 'kafka:9092',  # Replace with your Kafka bootstrap servers
    'group.id': 'my_group',  # Replace with your consumer group
    'auto.offset.reset': 'earliest',
}

# Create Kafka consumer
consumer = Consumer(kafka_conf)
# Subscribe to topic
consumer.subscribe(['Results'])  # Replace with your Kafka topic

# Create InfluxDB client
client = InfluxDBClient(url=influxdb_url, token=token, org=org)
write_api = client.write_api(write_options=SYNCHRONOUS)

try:
    while True:
        msg = consumer.poll(1.0)  # Poll for messages

        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                # End of partition event
                print(f"{msg.topic()} [{msg.partition()}] reached end at offset {msg.offset()}")
            elif msg.error():
                raise KafkaException(msg.error())
        else:
            # Proper message
            data_point = json.loads(msg.value().decode('utf-8'))
            #print(f"Received message: {data_point}")

            # Convert timestamp to nanoseconds to match InfluxDB precision
            data_point['Timestamp'] = int(float(data_point['Timestamp']) * 1e9)

            # Create a Point structure for InfluxDB
            point = Point("Results").tag("PowerLineID", data_point["PowerLineID"]) \
                                             .field("PowerFlowValue", data_point["PowerFlowValue"]) \
                                             .field("PowerChange", data_point["PowerChange"]) \
                                             .field("Predicted_IsSignificantChange", data_point["Predicted_IsSignificantChange"]) \
                                             .time(data_point['Timestamp'], WritePrecision.NS)

            print(f"Writing the following point to InfluxDB: {point.to_line_protocol()}")
            write_api.write(bucket=bucket, org=org, record=point)

except KeyboardInterrupt:
    pass
except Exception as e:
    print(f"Exception in consumption: {e}")
finally:
    # Close down consumer and InfluxDB client to commit final offsets.
    consumer.close()
    client.close()
# Out:
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702616400.0, 'PowerFlowValue': 434.6133333333333, 'PowerChange': 15.589166666666642, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=15.589166666666642,PowerFlowValue=434.6133333333333,Predicted_IsSignificantChange=1 1702616400000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702620000.0, 'PowerFlowValue': 387.5525, 'PowerChange': -47.06083333333328, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-47.06083333333328,PowerFlowValue=387.5525,Predicted_IsSignificantChange=1 1702620000000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702623600.0, 'PowerFlowValue': 353.23083333333335, 'PowerChange': -34.32166666666666, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-34.32166666666666,PowerFlowValue=353.23083333333335,Predicted_IsSignificantChange=1 1702623600000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702627200.0, 'PowerFlowValue': 285.8616666666666, 'PowerChange': -67.36916666666673, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-67.36916666666673,PowerFlowValue=285.8616666666666,Predicted_IsSignificantChange=1 1702627200000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702630800.0, 'PowerFlowValue': 272.09166666666664, 'PowerChange': -13.769999999999982, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-13.769999999999982,PowerFlowValue=272.09166666666664,Predicted_IsSignificantChange=1 1702630800000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702634400.0, 'PowerFlowValue': 219.03166666666667, 'PowerChange': -53.059999999999974, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-53.059999999999974,PowerFlowValue=219.03166666666667,Predicted_IsSignificantChange=1 1702634400000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702638000.0, 'PowerFlowValue': 165.2675, 'PowerChange': -53.764166666666654, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-53.764166666666654,PowerFlowValue=165.2675,Predicted_IsSignificantChange=1 1702638000000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702641600.0, 'PowerFlowValue': 145.92166666666665, 'PowerChange': -19.34583333333336, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange=-19.34583333333336,PowerFlowValue=145.92166666666665,Predicted_IsSignificantChange=1 1702641600000000000
# Received message: {'PowerLineID': '0.0', 'Timestamp': 1702645200.0, 'PowerFlowValue': 210.71, 'PowerChange': 64.78833333333336, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=0.0 PowerChange
000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702638000.0, 'PowerFlowValue': -126.71833333333332, 'PowerChange': -33.78083333333332, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-33.78083333333332,PowerFlowValue=-126.71833333333332,Predicted_IsSignificantChange=1 1702638000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702641600.0, 'PowerFlowValue': -168.13333333333333, 'PowerChange': -41.415000000000006, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-41.415000000000006,PowerFlowValue=-168.13333333333333,Predicted_IsSignificantChange=1 1702641600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702645200.0, 'PowerFlowValue': -108.24333374999999, 'PowerChange': 59.889999583333335, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=59.889999583333335,PowerFlowValue=-108.24333374999999,Predicted_IsSignificantChange=1 1702645200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702648800.0, 'PowerFlowValue': -91.38583333333334, 'PowerChange': 16.857500416666653, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=16.857500416666653,PowerFlowValue=-91.38583333333334,Predicted_IsSignificantChange=1 1702648800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702652400.0, 'PowerFlowValue': -101.05, 'PowerChange': -9.66416666666666, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-9.66416666666666,PowerFlowValue=-101.05,Predicted_IsSignificantChange=1 1702652400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702656000.0, 'PowerFlowValue': -101.02166666666666, 'PowerChange': 0.028333333333335986, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=0.028333333333335986,PowerFlowValue=-101.02166666666666,Predicted_IsSignificantChange=0 1702656000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702659600.0, 'PowerFlowValue': -63.31583333333333, 'PowerChange': 37.70583333333333, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=37.70583333333333,PowerFlowValue=-63.31583333333333,Predicted_IsSignificantChange=1 1702659600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702663200.0, 'PowerFlowValue': -91.95166666666667, 'PowerChange': -28.635833333333338, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-28.635833333333338,PowerFlowValue=-91.95166666666667,Predicted_IsSignificantChange=1 1702663200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702666800.0, 'PowerFlowValue': -54.99666666666667, 'PowerChange': 36.955, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=36.955,PowerFlowValue=-54.99666666666667,Predicted_IsSignificantChange=1 1702666800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702670400.0, 'PowerFlowValue': -28.985, 'PowerChange': 26.01166666666667, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=26.01166666666667,PowerFlowValue=-28.985,Predicted_IsSignificantChange=1 1702670400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702674000.0, 'PowerFlowValue': -64.185, 'PowerChange': -35.2, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-35.2,PowerFlowValue=-64.185,Predicted_IsSignificantChange=1 1702674000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702677600.0, 'PowerFlowValue': -86.18833333333333, 'PowerChange': -22.00333333333333, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-22.00333333333333,PowerFlowValue=-86.18833333333333,Predicted_IsSignificantChange=1 1702677600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702681200.0, 'PowerFlowValue': -78.93416666666667, 'PowerChange': 7.254166666666663, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=7.254166666666663,PowerFlowValue=-78.93416666666667,Predicted_IsSignificantChange=1 1702681200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702684800.0, 'PowerFlowValue': 1.7316666666666662, 'PowerChange': 80.66583333333334, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=80.66583333333334,PowerFlowValue=1.7316666666666662,Predicted_IsSignificantChange=1 1702684800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702688400.0, 'PowerFlowValue': -17.155833333333334, 'PowerChange': -18.8875, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-18.8875,PowerFlowValue=-17.155833333333334,Predicted_IsSignificantChange=1 1702688400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702692000.0, 'PowerFlowValue': -27.284166749999997, 'PowerChange': -10.128333416666663, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-10.128333416666663,PowerFlowValue=-27.284166749999997,Predicted_IsSignificantChange=1 1702692000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702695600.0, 'PowerFlowValue': -0.5008333333333334, 'PowerChange': 26.783333416666665, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=26.783333416666665,PowerFlowValue=-0.5008333333333334,Predicted_IsSignificantChange=1 1702695600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702699200.0, 'PowerFlowValue': 22.765, 'PowerChange': 23.265833333333333, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=23.265833333333333,PowerFlowValue=22.765,Predicted_IsSignificantChange=1 1702699200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702702800.0, 'PowerFlowValue': 25.260833316666666, 'PowerChange': 2.4958333166666655, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=2.4958333166666655,PowerFlowValue=25.260833316666666,Predicted_IsSignificantChange=1 1702702800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702706400.0, 'PowerFlowValue': -10.157499999999999, 'PowerChange': -35.41833331666666, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-35.41833331666666,PowerFlowValue=-10.157499999999999,Predicted_IsSignificantChange=1 1702706400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702710000.0, 'PowerFlowValue': -33.214999999999996, 'PowerChange': -23.057499999999997, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-23.057499999999997,PowerFlowValue=-33.214999999999996,Predicted_IsSignificantChange=1 1702710000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702713600.0, 'PowerFlowValue': -26.115, 'PowerChange': 7.099999999999998, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=7.099999999999998,PowerFlowValue=-26.115,Predicted_IsSignificantChange=1 1702713600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702717200.0, 'PowerFlowValue': -61.005833333333335, 'PowerChange': -34.89083333333333, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-34.89083333333333,PowerFlowValue=-61.005833333333335,Predicted_IsSignificantChange=1 1702717200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702720800.0, 'PowerFlowValue': -56.681666666666665, 'PowerChange': 4.32416666666667, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=4.32416666666667,PowerFlowValue=-56.681666666666665,Predicted_IsSignificantChange=1 1702720800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702724400.0, 'PowerFlowValue': -38.3075, 'PowerChange': 18.374166666666667, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=18.374166666666667,PowerFlowValue=-38.3075,Predicted_IsSignificantChange=1 1702724400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702728000.0, 'PowerFlowValue': -139.385, 'PowerChange': -101.07749999999999, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-101.07749999999999,PowerFlowValue=-139.385,Predicted_IsSignificantChange=1 1702728000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702731600.0, 'PowerFlowValue': -140.5675, 'PowerChange': -1.1825000000000045, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-1.1825000000000045,PowerFlowValue=-140.5675,Predicted_IsSignificantChange=0 1702731600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702735200.0, 'PowerFlowValue': -158.44833333333332, 'PowerChange': -17.880833333333328, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-17.880833333333328,PowerFlowValue=-158.44833333333332,Predicted_IsSignificantChange=1 1702735200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702738800.0, 'PowerFlowValue': -157.89000000000001, 'PowerChange': 0.5583333333333087, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=0.5583333333333087,PowerFlowValue=-157.89000000000001,Predicted_IsSignificantChange=0 1702738800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702742400.0, 'PowerFlowValue': -159.48916666666668, 'PowerChange': -1.5991666666666617, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-1.5991666666666617,PowerFlowValue=-159.48916666666668,Predicted_IsSignificantChange=0 1702742400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702746000.0, 'PowerFlowValue': -84.60333333333334, 'PowerChange': 74.88583333333334, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=74.88583333333334,PowerFlowValue=-84.60333333333334,Predicted_IsSignificantChange=1 1702746000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702749600.0, 'PowerFlowValue': -112.92416666666666, 'PowerChange': -28.320833333333326, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-28.320833333333326,PowerFlowValue=-112.92416666666666,Predicted_IsSignificantChange=1 1702749600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702753200.0, 'PowerFlowValue': -72.4475, 'PowerChange': 40.47666666666666, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=40.47666666666666,PowerFlowValue=-72.4475,Predicted_IsSignificantChange=1 1702753200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702756800.0, 'PowerFlowValue': -66.33166666666666, 'PowerChange': 6.115833333333342, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=6.115833333333342,PowerFlowValue=-66.33166666666666,Predicted_IsSignificantChange=1 1702756800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702760400.0, 'PowerFlowValue': -98.56416666666667, 'PowerChange': -32.2325, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-32.2325,PowerFlowValue=-98.56416666666667,Predicted_IsSignificantChange=1 1702760400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702764000.0, 'PowerFlowValue': -120.4825, 'PowerChange': -21.918333333333337, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-21.918333333333337,PowerFlowValue=-120.4825,Predicted_IsSignificantChange=1 1702764000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702767600.0, 'PowerFlowValue': -181.245, 'PowerChange': -60.7625, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-60.7625,PowerFlowValue=-181.245,Predicted_IsSignificantChange=1 1702767600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702771200.0, 'PowerFlowValue': -135.16, 'PowerChange': 46.08500000000001, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=46.08500000000001,PowerFlowValue=-135.16,Predicted_IsSignificantChange=1 1702771200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702774800.0, 'PowerFlowValue': -130.61333333333332, 'PowerChange': 4.546666666666681, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=4.546666666666681,PowerFlowValue=-130.61333333333332,Predicted_IsSignificantChange=1 1702774800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702778400.0, 'PowerFlowValue': -123.45, 'PowerChange': 7.163333333333313, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=7.163333333333313,PowerFlowValue=-123.45,Predicted_IsSignificantChange=1 1702778400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702782000.0, 'PowerFlowValue': -51.56583333333333, 'PowerChange': 71.88416666666667, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=71.88416666666667,PowerFlowValue=-51.56583333333333,Predicted_IsSignificantChange=1 1702782000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702785600.0, 'PowerFlowValue': -32.572916666666664, 'PowerChange': 18.992916666666666, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=18.992916666666666,PowerFlowValue=-32.572916666666664,Predicted_IsSignificantChange=1 1702785600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702789200.0, 'PowerFlowValue': -49.915000166666665, 'PowerChange': -17.3420835, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-17.3420835,PowerFlowValue=-49.915000166666665,Predicted_IsSignificantChange=1 1702789200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702792800.0, 'PowerFlowValue': -59.96666666666667, 'PowerChange': -10.051666500000003, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-10.051666500000003,PowerFlowValue=-59.96666666666667,Predicted_IsSignificantChange=1 1702792800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702796400.0, 'PowerFlowValue': -78.32000000000001, 'PowerChange': -18.35333333333334, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-18.35333333333334,PowerFlowValue=-78.32000000000001,Predicted_IsSignificantChange=1 1702796400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702800000.0, 'PowerFlowValue': -100.35416666666667, 'PowerChange': -22.034166666666664, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-22.034166666666664,PowerFlowValue=-100.35416666666667,Predicted_IsSignificantChange=1 1702800000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702803600.0, 'PowerFlowValue': -160.12916666666666, 'PowerChange': -59.77499999999999, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-59.77499999999999,PowerFlowValue=-160.12916666666666,Predicted_IsSignificantChange=1 1702803600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702807200.0, 'PowerFlowValue': -205.45916666666668, 'PowerChange': -45.33000000000001, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-45.33000000000001,PowerFlowValue=-205.45916666666668,Predicted_IsSignificantChange=1 1702807200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702810800.0, 'PowerFlowValue': -221.4425, 'PowerChange': -15.98333333333332, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-15.98333333333332,PowerFlowValue=-221.4425,Predicted_IsSignificantChange=1 1702810800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702814400.0, 'PowerFlowValue': -293.0025, 'PowerChange': -71.56, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-71.56,PowerFlowValue=-293.0025,Predicted_IsSignificantChange=1 1702814400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702818000.0, 'PowerFlowValue': -262.7341666666667, 'PowerChange': 30.268333333333317, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=30.268333333333317,PowerFlowValue=-262.7341666666667,Predicted_IsSignificantChange=1 1702818000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702821600.0, 'PowerFlowValue': -273.0725, 'PowerChange': -10.33833333333331, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-10.33833333333331,PowerFlowValue=-273.0725,Predicted_IsSignificantChange=1 1702821600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702825200.0, 'PowerFlowValue': -230.21416666666667, 'PowerChange': 42.85833333333332, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=42.85833333333332,PowerFlowValue=-230.21416666666667,Predicted_IsSignificantChange=1 1702825200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702828800.0, 'PowerFlowValue': -182.2770833333333, 'PowerChange': 47.93708333333336, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=47.93708333333336,PowerFlowValue=-182.2770833333333,Predicted_IsSignificantChange=1 1702828800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702832400.0, 'PowerFlowValue': -203.6883325, 'PowerChange': -21.411249166666693, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-21.411249166666693,PowerFlowValue=-203.6883325,Predicted_IsSignificantChange=1 1702832400000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702836000.0, 'PowerFlowValue': -227.7825, 'PowerChange': -24.094167499999998, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-24.094167499999998,PowerFlowValue=-227.7825,Predicted_IsSignificantChange=1 1702836000000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702839600.0, 'PowerFlowValue': -176.92166666666665, 'PowerChange': 50.860833333333346, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=50.860833333333346,PowerFlowValue=-176.92166666666665,Predicted_IsSignificantChange=1 1702839600000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702843200.0, 'PowerFlowValue': -127.16333333333334, 'PowerChange': 49.75833333333331, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=49.75833333333331,PowerFlowValue=-127.16333333333334,Predicted_IsSignificantChange=1 1702843200000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702846800.0, 'PowerFlowValue': -147.43, 'PowerChange': -20.266666666666666, 'Predicted_IsSignificantChange': 1.0}
# Writing the following point to InfluxDB: Results,PowerLineID=1.0 PowerChange=-20.266666666666666,PowerFlowValue=-147.43,Predicted_IsSignificantChange=1 1702846800000000000
# Received message: {'PowerLineID': '1.0', 'Timestamp': 1702850400.0, 'PowerFlowValue': -200.79083333333335, 'PowerChange': -53.360833333333346, 'Predicted_IsSignificantChange': 1.0}
# ...
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702742400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702746000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702746000000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702749600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702749600000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702753200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702753200000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702756800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702756800000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702760400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702760400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702764000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702764000000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702767600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702767600000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702771200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702771200000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702774800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702774800000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702778400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702778400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702782000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702782000000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702785600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702785600000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702789200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702789200000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702792800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702792800000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702796400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702796400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702800000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702800000000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702803600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702803600000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702807200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702807200000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702810800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702810800000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702814400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702814400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702818000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702818000000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702821600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702821600000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702825200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702825200000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702828800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702828800000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702832400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702832400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702836000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702836000000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702839600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702839600000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702843200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702843200000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702846800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702846800000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702850400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702850400000000000
# Received message: {'PowerLineID': '51.0', 'Timestamp': 1702854000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=51.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702854000000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702605600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702605600000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702609200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702609200000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702612800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702612800000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702616400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702616400000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702620000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702620000000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702623600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702623600000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702627200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702627200000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702630800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702630800000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702634400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702634400000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702638000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702638000000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702641600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702641600000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702645200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702645200000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702648800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702648800000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702652400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702652400000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702656000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702656000000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702659600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702659600000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702663200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702663200000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702666800.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702666800000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702670400.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702670400000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702674000.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702674000000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702677600.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702677600000000000
# Received message: {'PowerLineID': '52.0', 'Timestamp': 1702681200.0, 'PowerFlowValue': 0.0, 'PowerChange': 0.0, 'Predicted_IsSignificantChange': 0.0}
# Writing the following point to InfluxDB: Results,PowerLineID=52.0 PowerChange=0,PowerFlowValue=0,Predicted_IsSignificantChange=0 1702681200000000000
