# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /home/sinda/anaconda3/lib/python3.11/site-packages (4.6.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/sinda/anaconda3/lib/python3.11/site-packages (from pymongo) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from pymongo import MongoClient

# MongoDB connection settings
username = 'root'  # Replace with your MongoDB username
password = 'root'  # Replace with your MongoDB password
mongo_uri = f"mongodb://{username}:{password}@mongodb:27017/"
database_name = "Epsymolo"
collection_name = "power_flow_data"

# Initialize MongoDB client
client = MongoClient(mongo_uri)
db = client[database_name]
collection = db[collection_name]

# Directory containing your CSV files
csv_directory = "Data"

# Iterate through CSV files in the directory
for filename in os.listdir(csv_directory):
    if filename.endswith(".csv"):
        csv_path = os.path.join(csv_directory, filename)
        # Read CSV into a pandas DataFrame
        df = pd.read_csv(csv_path)
        # Convert DataFrame to a list of dictionaries (each row)
        data = df.to_dict(orient="records")
        # Insert data into MongoDB collection
        collection.insert_many(data)
        print(f"Uploaded {len(data)} documents from {filename}")

# Close MongoDB connection
client.close()
# Out:
# Uploaded 24 documents from 2010-08-25.csv
# Uploaded 24 documents from 2010-09-05.csv
# Uploaded 24 documents from 2010-08-17.csv
# Uploaded 24 documents from 2010-09-16.csv
# Uploaded 24 documents from 2010-07-20.csv
# Uploaded 24 documents from 2010-07-04.csv
# Uploaded 24 documents from 2010-09-17.csv
# Uploaded 24 documents from 2010-08-18.csv
# Uploaded 24 documents from 2010-07-15.csv
# Uploaded 24 documents from 2010-07-08.csv
# Uploaded 24 documents from 2010-08-21.csv
# Uploaded 24 documents from 2010-07-23.csv
# Uploaded 24 documents from 2010-08-10.csv
# Uploaded 24 documents from 2010-07-02.csv
# Uploaded 24 documents from 2010-09-15.csv
# Uploaded 24 documents from 2010-07-24.csv
# Uploaded 24 documents from 2010-07-29.csv
# Uploaded 24 documents from 2010-08-01.csv
# Uploaded 24 documents from 2010-08-03.csv
# Uploaded 24 documents from 2010-09-12.csv
# Uploaded 24 documents from 2010-09-23.csv
# Uploaded 24 documents from 2010-08-04.csv
# Uploaded 24 documents from 2010-09-02.csv
# Uploaded 24 documents from 2010-07-26.csv
# Uploaded 24 documents from 2010-08-26.csv
# Uploaded 24 documents from 2010-07-25.csv
# Uploaded 24 documents from 2010-07-05.csv
# Uploaded 24 documents from 2010-09-11.csv
# Uploaded 24 documents from 2010-08-20.csv
# Uploaded 24 documents from 2010-08-31.csv
# Uploaded 24 documents from 2010-09-03.csv
# Uploaded 24 documents from 2010-07-22.csv
